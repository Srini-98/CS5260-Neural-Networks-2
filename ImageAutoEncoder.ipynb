# %%
import numpy as np
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
from torchvision import transforms

import torch

a = torch.randn(5,3)

b = torch.flatten(a)

c = b.view(a.shape[0] , a.shape[1])

print(a.shape[0])
print(a.shape[1])
print(a.shape)
print(b)

print(c)
# Out:
# 5
# 3
# torch.Size([5, 3])
# tensor([ 1.8063, -0.1446,  0.4808, -1.3045,  0.3946, -0.6175, -0.3307, -0.5379,
#          0.7020,  0.7159,  0.2873, -1.1844,  1.1351, -0.3666,  0.9283])
# tensor([[ 1.8063, -0.1446,  0.4808],
#         [-1.3045,  0.3946, -0.6175],
#         [-0.3307, -0.5379,  0.7020],
#         [ 0.7159,  0.2873, -1.1844],
#         [ 1.1351, -0.3666,  0.9283]])

# %%
import os 

path = "./dataset/images/"
image_lis = os.listdir(path)

# %%
input_size = 224
data_transforms = transforms.Compose([
        transforms.RandomResizedCrop(input_size),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ])

# %%
class ImageAutoEncoder(nn.Module):
    def __init__(self):
        super(ImageAutoEncoder, self).__init__()
        
        #Encoder
        self.conv1 = nn.Conv2d(3, 16, 3, padding=1)  
        self.conv2 = nn.Conv2d(16, 4, 3, padding=1)
        self.pool = nn.MaxPool2d(2, 2)
        
        self.linear_1 = nn.Linear(12544 , 1200)
        self.linear_2 = nn.Linear(1200 , 200)
        
        self.delinear_1 = nn.Linear(200 , 1200)
        self.delinear_2 = nn.Linear(1200 , 12544)
        
        #Decoder
        #self.t_conv1 = nn.ConvTranspose2d(4, 16, 2, stride=2)
        #self.t_conv2 = nn.ConvTranspose2d(16, 3, 2, stride=2)
        
        self.deconv1 = nn.ConvTranspose2d(1, 16, 3, stride=2, output_padding=1)
        self.deconv2 = nn.ConvTranspose2d(16, 3, 3, stride=1, padding = 2, output_padding=0)
        
    def forward(self , x):
        x = F.relu(self.conv1(x))
        x = self.pool(x)
        x = F.relu(self.conv2(x))
        x = self.pool(x)
        
        x = torch.flatten(x ,start_dim = 1)
        x = nn.ReLU()(self.linear_1(x))
        x = nn.ReLU()(self.linear_2(x))
        
        #start of decoder
        x = nn.ReLU()(self.delinear_1(x))
        x = nn.ReLU()(self.delinear_2(x))
        x = x.view(-1 , 1 , 112 , 112)
        x = nn.ReLU()(self.deconv1(x))
        x = self.deconv2(x)
        
        
        #print("X.shape" , x.shape)
        
        return x

# %%
import pandas as pd
df_csv = pd.read_csv("./dataset/books_with_genres.csv")

# %%
df_csv.columns
# Out:
# Index(['isbn', 'text_reviews_count', 'series', 'country_code', 'language_code',
#        'popular_shelves', 'asin', 'is_ebook', 'average_rating', 'kindle_asin',
#        'similar_books', 'description', 'format', 'link', 'authors',
#        'publisher', 'num_pages', 'publication_day', 'isbn13',
#        'publication_month', 'edition_information', 'publication_year', 'url',
#        'image_url', 'book_id', 'ratings_count', 'work_id', 'title',
#        'title_without_series', 'history, historical fiction, biography',
#        'fiction', 'fantasy, paranormal', 'mystery, thriller, crime', 'poetry',
#        'romance', 'non-fiction', 'children', 'young-adult', 'comics, graphic',
#        'category', 'binary_category'],
#       dtype='object')

# %%
df_csv["fiction_binary"] = np.where(df_csv['binary_category']=='fiction', 1, 0)
y = df_csv['fiction_binary']

# %%
import torch
from PIL import Image
ind = 0
batch_size = 32
book_id , category = df_csv['book_id'] , df_csv['fiction_binary']
input_list = []
for i in book_id:
    im = Image.open(path + str(i))
    im_rgb = im.convert("RGB")
    input_tensor = data_transforms(im_rgb)
    input_list.append(input_tensor)

# %%
input_X = torch.stack(input_list).cuda()
input_Y = torch.LongTensor(y).cuda()

# %%
print(input_Y.shape)
print(input_X.shape)
# Out:
# torch.Size([5000])
# torch.Size([5000, 3, 224, 224])

# %%
model = ImageAutoEncoder().cuda()
criterion = nn.MSELoss()

optimizer = torch.optim.Adam(model.parameters() , lr = 0.001)

# %%
epoch_count = 100
batch_size = 32
for i in range(0 , epoch_count):
    print("iteration number " , i + 1)
    train_loss = 0
    for j in range(0 , len(input_X) , 32):
        img = input_X[j:j+32]#.unsqueeze(0)
        #print(img.shape)
        img.requires_grad_ = False
        X_predicted = model.forward(img)
        loss = criterion(X_predicted , img)
        train_loss += loss
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    print("Loss is " ,train_loss)
# Out:
# iteration number  1
# Loss is  tensor(213.8831, device='cuda:0', grad_fn=<AddBackward0>)
# iteration number  2
# Loss is  tensor(147.8370, device='cuda:0', grad_fn=<AddBackward0>)
# iteration number  3
# Loss is  tensor(132.9646, device='cuda:0', grad_fn=<AddBackward0>)
# iteration number  4
# Loss is  tensor(124.6258, device='cuda:0', grad_fn=<AddBackward0>)
# iteration number  5
# Loss is  tensor(120.4789, device='cuda:0', grad_fn=<AddBackward0>)
# iteration number  6
# Loss is  tensor(116.2557, device='cuda:0', grad_fn=<AddBackward0>)
# iteration number  7
# Loss is  tensor(113.5704, device='cuda:0', grad_fn=<AddBackward0>)
# iteration number  8
# Loss is  tensor(110.1972, device='cuda:0', grad_fn=<AddBackward0>)
# iteration number  9
# Loss is  tensor(107.7115, device='cuda:0', grad_fn=<AddBackward0>)
# iteration number  10
# Loss is  tensor(105.8790, device='cuda:0', grad_fn=<AddBackward0>)
# iteration number  11
# Loss is  tensor(104.5052, device='cuda:0', grad_fn=<AddBackward0>)
# iteration number  12
# Loss is  tensor(103.6688, device='cuda:0', grad_fn=<AddBackward0>)
# iteration number  13
# Loss is  tensor(103.4638, device='cuda:0', grad_fn=<AddBackward0>)
# iteration number  14
# Loss is  tensor(100.2640, device='cuda:0', grad_fn=<AddBackward0>)
# iteration number  15
# Loss is  tensor(98.2894, device='cuda:0', grad_fn=<AddBackward0>)
# iteration number  16
# Loss is  tensor(97.3315, device='cuda:0', grad_fn=<AddBackward0>)
# iteration number  17
# Loss is  tensor(97.5913, device='cuda:0', grad_fn=<AddBackward0>)
# iteration number  18
# Loss is  tensor(98.3852, device='cuda:0', grad_fn=<AddBackward0>)
# iteration number  19
# Loss is  tensor(96.1405, device='cuda:0', grad_fn=<AddBackward0>)
# iteration number  20
# Loss is  tensor(94.3126, device='cuda:0', grad_fn=<AddBackward0>)
# iteration number  21
# Loss is  tensor(92.8358, device='cuda:0', grad_fn=<AddBackward0>)
# iteration number  22
# Loss is  tensor(91.8966, device='cuda:0', grad_fn=<AddBackward0>)
# iteration number  23
# Loss is  tensor(91.5357, device='cuda:0', grad_fn=<AddBackward0>)
# iteration number  24
# Loss is  tensor(91.0680, device='cuda:0', grad_fn=<AddBackward0>)
# iteration number  25
# Loss is  tensor(90.9311, device='cuda:0', grad_fn=<AddBackward0>)
# iteration number  26
# Loss is  tensor(90.1117, device='cuda:0', grad_fn=<AddBackward0>)
# iteration number  27
# Loss is  tensor(89.2172, device='cuda:0', grad_fn=<AddBackward0>)
# iteration number  28
# Loss is  tensor(89.3086, device='cuda:0', grad_fn=<AddBackward0>)
# iteration number  29
# Loss is  tensor(89.8296, device='cuda:0', grad_fn=<AddBackward0>)
# iteration number  30
# Loss is  tensor(88.9184, device='cuda:0', grad_fn=<AddBackward0>)
# iteration number  31
# Loss is  tensor(88.1066, device='cuda:0', grad_fn=<AddBackward0>)
# iteration number  32
# Loss is  tensor(87.4224, device='cuda:0', grad_fn=<AddBackward0>)
# iteration number  33
# Loss is  tensor(86.5537, device='cuda:0', grad_fn=<AddBackward0>)
# iteration number  34
# Loss is  tensor(85.6485, device='cuda:0', grad_fn=<AddBackward0>)
# iteration number  35
# Loss is  tensor(85.0239, device='cuda:0', grad_fn=<AddBackward0>)
# iteration number  36
# Loss is  tensor(84.3978, device='cuda:0', grad_fn=<AddBackward0>)
# iteration number  37
# Loss is  tensor(84.1205, device='cuda:0', grad_fn=<AddBackward0>)
# iteration number  38
# Loss is  tensor(84.0714, device='cuda:0', grad_fn=<AddBackward0>)
# iteration number  39
# Loss is  tensor(84.1824, device='cuda:0', grad_fn=<AddBackward0>)
# iteration number  40
# Loss is  tensor(85.6979, device='cuda:0', grad_fn=<AddBackward0>)
# iteration number  41
# Loss is  tensor(85.6229, device='cuda:0', grad_fn=<AddBackward0>)
# iteration number  42
# Loss is  tensor(82.3961, device='cuda:0', grad_fn=<AddBackward0>)
# iteration number  43
# Loss is  tensor(81.2325, device='cuda:0', grad_fn=<AddBackward0>)
# iteration number  44
# Loss is  tensor(80.8195, device='cuda:0', grad_fn=<AddBackward0>)
# iteration number  45
# Loss is  tensor(80.6705, device='cuda:0', grad_fn=<AddBackward0>)
# iteration number  46
# Loss is  tensor(80.8061, device='cuda:0', grad_fn=<AddBackward0>)
# iteration number  47
# Loss is  tensor(81.2119, device='cuda:0', grad_fn=<AddBackward0>)
# iteration number  48
# Loss is  tensor(81.1565, device='cuda:0', grad_fn=<AddBackward0>)
# iteration number  49
# Loss is  tensor(81.0794, device='cuda:0', grad_fn=<AddBackward0>)
# iteration number  50
# Loss is  tensor(80.8599, device='cuda:0', grad_fn=<AddBackward0>)
# iteration number  51
# Loss is  tensor(80.5237, device='cuda:0', grad_fn=<AddBackward0>)
# iteration number  52
# Loss is  tensor(81.0838, device='cuda:0', grad_fn=<AddBackward0>)
# iteration number  53
# Loss is  tensor(81.6188, device='cuda:0', grad_fn=<AddBackward0>)
# iteration number  54
# Loss is  tensor(80.8929, device='cuda:0', grad_fn=<AddBackward0>)
# iteration number  55
# Loss is  tensor(79.8399, device='cuda:0', grad_fn=<AddBackward0>)
# iteration number  56
# Loss is  tensor(78.7718, device='cuda:0', grad_fn=<AddBackward0>)
# iteration number  57
# Loss is  tensor(78.2888, device='cuda:0', grad_fn=<AddBackward0>)
# iteration number  58
# Loss is  tensor(78.7786, device='cuda:0', grad_fn=<AddBackward0>)
# iteration number  59
# Loss is  tensor(79.2487, device='cuda:0', grad_fn=<AddBackward0>)
# iteration number  60
# Loss is  tensor(79.3263, device='cuda:0', grad_fn=<AddBackward0>)
# iteration number  61
# Loss is  tensor(79.5207, device='cuda:0', grad_fn=<AddBackward0>)
# iteration number  62
# Loss is  tensor(80.4721, device='cuda:0', grad_fn=<AddBackward0>)
# iteration number  63
# Loss is  tensor(78.5273, device='cuda:0', grad_fn=<AddBackward0>)
# iteration number  64
# Loss is  tensor(77.9296, device='cuda:0', grad_fn=<AddBackward0>)
# iteration number  65
# Loss is  tensor(77.6208, device='cuda:0', grad_fn=<AddBackward0>)
# iteration number  66
# Loss is  tensor(77.1900, device='cuda:0', grad_fn=<AddBackward0>)
# iteration number  67
# Loss is  tensor(77.2726, device='cuda:0', grad_fn=<AddBackward0>)
# iteration number  68
# Loss is  tensor(77.8670, device='cuda:0', grad_fn=<AddBackward0>)
# iteration number  69
# Loss is  tensor(79.8829, device='cuda:0', grad_fn=<AddBackward0>)
# iteration number  70
# Loss is  tensor(80.0771, device='cuda:0', grad_fn=<AddBackward0>)
# iteration number  71
# Loss is  tensor(77.6800, device='cuda:0', grad_fn=<AddBackward0>)
# iteration number  72
# Loss is  tensor(77.0747, device='cuda:0', grad_fn=<AddBackward0>)
# iteration number  73
# Loss is  tensor(77.3337, device='cuda:0', grad_fn=<AddBackward0>)
# iteration number  74
# Loss is  tensor(76.3634, device='cuda:0', grad_fn=<AddBackward0>)
# iteration number  75
# Loss is  tensor(75.5722, device='cuda:0', grad_fn=<AddBackward0>)
# iteration number  76
# Loss is  tensor(74.8103, device='cuda:0', grad_fn=<AddBackward0>)
# iteration number  77
# Loss is  tensor(74.4239, device='cuda:0', grad_fn=<AddBackward0>)
# iteration number  78
# Loss is  tensor(74.3789, device='cuda:0', grad_fn=<AddBackward0>)
# iteration number  79
# Loss is  tensor(74.4625, device='cuda:0', grad_fn=<AddBackward0>)
# iteration number  80
# Loss is  tensor(74.5217, device='cuda:0', grad_fn=<AddBackward0>)
# iteration number  81
# Loss is  tensor(74.6382, device='cuda:0', grad_fn=<AddBackward0>)
# iteration number  82
# Loss is  tensor(74.5803, device='cuda:0', grad_fn=<AddBackward0>)
# iteration number  83
# Loss is  tensor(74.6740, device='cuda:0', grad_fn=<AddBackward0>)
# iteration number  84
# Loss is  tensor(75.1804, device='cuda:0', grad_fn=<AddBackward0>)
# iteration number  85
# Loss is  tensor(75.8405, device='cuda:0', grad_fn=<AddBackward0>)
# iteration number  86
# Loss is  tensor(76.8410, device='cuda:0', grad_fn=<AddBackward0>)
# iteration number  87
# Loss is  tensor(78.5797, device='cuda:0', grad_fn=<AddBackward0>)
# iteration number  88
# Loss is  tensor(79.1480, device='cuda:0', grad_fn=<AddBackward0>)
# iteration number  89
# Loss is  tensor(77.4616, device='cuda:0', grad_fn=<AddBackward0>)
# iteration number  90
# Loss is  tensor(76.4010, device='cuda:0', grad_fn=<AddBackward0>)
# iteration number  91
# Loss is  tensor(75.5356, device='cuda:0', grad_fn=<AddBackward0>)
# iteration number  92
# Loss is  tensor(74.7900, device='cuda:0', grad_fn=<AddBackward0>)
# iteration number  93
# Loss is  tensor(73.6024, device='cuda:0', grad_fn=<AddBackward0>)
# iteration number  94
# Loss is  tensor(72.7702, device='cuda:0', grad_fn=<AddBackward0>)
# iteration number  95
# Loss is  tensor(72.5551, device='cuda:0', grad_fn=<AddBackward0>)
# iteration number  96
# Loss is  tensor(72.7032, device='cuda:0', grad_fn=<AddBackward0>)
# iteration number  97
# Loss is  tensor(73.0023, device='cuda:0', grad_fn=<AddBackward0>)
# iteration number  98
# Loss is  tensor(73.2439, device='cuda:0', grad_fn=<AddBackward0>)
# iteration number  99
# Loss is  tensor(73.1914, device='cuda:0', grad_fn=<AddBackward0>)
# iteration number  100
# Loss is  tensor(73.0806, device='cuda:0', grad_fn=<AddBackward0>)

# %%
use_cuda = torch.cuda.is_available()
device = torch.device('cuda:0' if use_cuda else 'cpu')

def get_embeddings(x):
    
      #Encoder
    x = F.relu(model.conv1(x))
    x = model.pool(x)
    x = F.relu(model.conv2(x))
    x = model.pool(x)

    x = torch.flatten(x ,start_dim = 1)
    x = nn.ReLU()(model.linear_1(x))
    x = nn.ReLU()(model.linear_2(x))
    
    return x

embeddings = []
with torch.no_grad():
    for i in book_id:
        im = Image.open(path + str(i))
        im_rgb = im.convert("RGB")
        input_tensor = data_transforms(im_rgb)
        input_tensor = input_tensor.to(device)
        val = get_embeddings(input_tensor.unsqueeze(0))
        embeddings.append({str(i) : val})

# %%
print(len(embeddings))
# Out:
# 5000

# %%
torch.save(embeddings, "embeddings_conv_encoder_decoder.pkl")
